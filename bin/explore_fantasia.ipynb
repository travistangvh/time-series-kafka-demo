# %%
# Find all unique data types

# %%
import glob
import wfdb
all_records = glob.glob("/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/**/**/**.hea")

d = {}
for record in all_records:
    try:
        record = wfdb.rdrecord(record[:-4])
        for sig_name in record.__dict__['sig_name']:
            if sig_name not in d:
                d[sig_name] = 1
            else:
                d[sig_name]+=1
    except Exception as e:
        print(e)
        print(record)
        continue
# Out:
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p059936/3190851_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p059936/3064851_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p059936/3621475_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p059936/3154213_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p059936/3508696_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p059936/3346823_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p052529/3329332_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p052529/3033487_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p052529/3257943_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p052529/3863129_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p052529/3887447_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p052529/3434253_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p052529/3920444_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p052529/3052097_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p052529/3874148_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p052529/3942327_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p052529/3642797_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p052529/3863292_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p054183/3954449_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p054183/3888209_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p054183/3898135_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p054183/3504912_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p050015/3315501_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p056697/3296993_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p056697/3909491_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p056697/3131252_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p056697/3366395_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p056697/3247331_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p056697/3334577_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p056697/3069028_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p05/p055725/3967874_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p02/p026868/3039150_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p02/p026868/3842646_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p02/p024276/3172169_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p02/p024276/3519170_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p02/p024276/3393397_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p02/p021580/3086199_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p02/p021580/3548531_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p02/p029299/3495420_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p02/p029299/3364831_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p02/p029299/3016206_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p03/p031942/3986227_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p049037/3953487_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p041035/3944272_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p041035/3262930_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p041035/3170355_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p041035/3397206_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p044298/3638873_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p044298/3891496_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p046927/3072153_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p046927/3846501_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p046927/3071256_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p042525/3545730_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p042525/3900017_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p044083/3343009_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p044083/3314767_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p046057/3363215_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p043926/3826093_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p043926/3510715_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p043926/3565741_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p043926/3573880_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p042075/3749326_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p042075/3427580_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p046154/3617126_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p042995/3399556_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p04/p042995/3761186_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p01/p017002/3270227_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p06/p062323/3472714_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p06/p062323/3380943_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p06/p061282/3321307_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p06/p063762/3326564_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p06/p063762/3398756_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p06/p067617/3091867_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p06/p067617/3967563_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p06/p060436/3427584_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p06/p060436/3807034_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p06/p060659/3993385_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p06/p060659/3397563_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p08/p086678/3720080_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p08/p086678/3088309_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p08/p086678/3114082_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p08/p086678/3404948_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p08/p082512/3316415_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p08/p082512/3058380_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p08/p082512/3083867_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p08/p087675/3591887_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p08/p087675/3536647_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p08/p082104/3209370_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p08/p083873/3796452_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p09/p096305/3926353_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p09/p096305/3358560_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p09/p096305/3905126_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p09/p093705/3524457_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p09/p093705/3915623_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p09/p094300/3662302_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p09/p094300/3194415_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p09/p094300/3571579_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p09/p096060/3923396_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p09/p099756/3974531_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p09/p099756/3689356_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p09/p094255/3175813_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p07/p070723/3476173_layout.hea
# sampto must be greater than sampfrom
# /Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p00/p000194/3400942_layout.hea

# %%
def preprocess_scdh():
    # Read in the data
    record = wfdb.rdrecord(record[:-4])

    #

# %%
d
# Out:
# {'PLETH': 11,
#  'RESP': 11,
#  'II': 11,
#  'III': 3,
#  'V': 9,
#  'ABP': 6,
#  'AVR': 8,
#  'CVP': 2,
#  'MCL': 2}

# %%
d
# Out:
# {'PLETH': 3932,
#  'RESP': 4218,
#  'II': 4325,
#  'III': 524,
#  'V': 3724,
#  'ABP': 2448,
#  'AVR': 2430,
#  'CVP': 619,
#  'MCL': 297,
#  'HR': 97,
#  'PULSE': 96,
#  'ABP Sys': 34,
#  'ABP Dias': 34,
#  'ABP Mean': 34,
#  'NBP': 27,
#  'NBP Sys': 50,
#  'NBP Dias': 50,
#  'NBP Mean': 50,
#  'ST III': 50,
#  'ST V': 49,
#  'SpO2': 63,
#  'PVC Rate per Minute': 59,
#  'Rhythm Status': 59,
#  'Ectopic Status': 59,
#  'Ectopic Count': 57,
#  'I': 876,
#  'AVF': 19,
#  'AVL': 5,
#  'ABP SYS': 28,
#  'ABP DIAS': 28,
#  'ABP MEAN': 29,
#  'NBP SYS': 30,
#  'NBP DIAS': 30,
#  'NBP MEAN': 30,
#  'ST-III': 28,
#  'ST-V': 29,
#  '%SpO2': 32,
#  'PlsNBP': 24,
#  '[63131]': 31,
#  'Atrial Paced Beat Count': 31,
#  'Vent Paced Beat Count': 31,
#  'Dual Paced Beat Count': 31,
#  'Paced Beat Count': 31,
#  'Normal Beat Count': 31,
#  'SVPB Count': 31,
#  'PVC Count': 31,
#  'SV Count': 31,
#  'Missed Beat Count': 31,
#  'All Beat Count': 31,
#  'SVPB Run Count': 31,
#  'S Rate Max': 31,
#  'S Rate Min': 31,
#  'Paced Run Count': 31,
#  'P Rate Max': 31,
#  'P Rate Min': 31,
#  'VQ Run Count': 31,
#  'PVC Run Count': 31,
#  'V Rate Max': 31,
#  'V Rate Min': 31,
#  'Max PVC Run': 31,
#  'R On T Count': 31,
#  'PVC Pair Count': 31,
#  'Pacer Not Pace Count': 31,
#  'Pacer Not Capture Count': 31,
#  'Multiform Count': 31,
#  'Irregular HR Percent': 31,
#  'pNN50 Percent': 31,
#  'HR Variability': 31,
#  'Poor Signal': 31,
#  'Trigeminy Percent': 31,
#  'Bigeminy Percent': 31,
#  'Paced Beat Percent': 31,
#  'Atrial Paced Percent': 31,
#  'Dual Paced Percent': 31,
#  'Vent Paced Percent': 31,
#  'ST I': 22,
#  'ST II': 24,
#  'ST AVR': 22,
#  'ST AVL': 22,
#  'ST AVF': 22,
#  'ST MCL': 22,
#  'ST-I': 2,
#  'ST-II': 3,
#  'ST-aVR': 2,
#  'ST-aVL': 2,
#  'ST-aVF': 2,
#  'ST-MCL': 1,
#  'ART': 485,
#  'PAP': 156,
#  'T1': 3,
#  'Tcore': 2,
#  'Trect': 3,
#  'ART Sys': 10,
#  'ART Dias': 10,
#  'ART Mean': 10,
#  'Temp Rect': 2,
#  'PAP SYS': 15,
#  'PAP DIAS': 15,
#  'PAP MEAN': 15,
#  'ART SYS': 7,
#  'ART DIAS': 7,
#  'ART MEAN': 7,
#  'CO': 10,
#  'Tblood': 10,
#  'C.I.': 7,
#  'PAP Sys': 4,
#  'PAP Dias': 4,
#  'PAP Mean': 4,
#  'TEMP': 5,
#  'NBPSys': 6,
#  'NBPDias': 6,
#  'NBPMean': 6,
#  'AOBP': 11,
#  'AOBP Sys': 2,
#  'AOBP Dias': 2,
#  'AOBP Mean': 2,
#  'ICP': 89,
#  'UAP': 55,
#  'UAP Sys': 3,
#  'UAP Dias': 3,
#  'UAP Mean': 3,
#  'CPP': 2,
#  'aVL': 29,
#  'Ao SYS': 1,
#  'Ao DIAS': 1,
#  'Ao MEAN': 1,
#  'PAWP': 1,
#  'Tnaso': 2,
#  'aVR': 4}

# %%
record = wfdb.rdrecord('/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/fantasia-database-1.0.0/f1o01')
record

# %%
record.__dict__['sig_name']
# Out:
# ['RESP', 'ECG']

# %%
resampled = record.to_dataframe().resample('5S').first()

# %%
resampled
# Out:
#                   RESP     ECG
# 0 days 00:00:00  8.488   8.460
# 0 days 00:00:05  8.300   8.444
# 0 days 00:00:10  8.204   8.508
# 0 days 00:00:15  8.300   8.384
# 0 days 00:00:20  7.964   8.472
# ...                ...     ...
# 0 days 02:00:30  9.528  10.232
# 0 days 02:00:35  8.960   8.252
# 0 days 02:00:40  8.780   8.072
# 0 days 02:00:45  7.860   7.900
# 0 days 02:00:50  7.708   8.124
#
# [1451 rows x 2 columns]

# %%
import glob
import wfdb
scdh_records = glob.glob("/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/**.hea")

scdh_d = {}
for record in scdh_records:
    try:
        record = wfdb.rdrecord(record[:-4])
        for sig_name in record.__dict__['sig_name']:
            if sig_name not in scdh_d:
                scdh_d[sig_name] = 1
            else:
                scdh_d[sig_name]+=1
    except Exception as e:
        print(e)
        print(record)
        continue

# %%
wfdb.rdrecord('/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/42').to_dataframe()
# Out:
#                             ECG      ECG
# 0 days 00:00:00        -1.41125  0.69000
# 0 days 00:00:00.004000 -1.44000  0.70375
# 0 days 00:00:00.008000 -1.43125  0.69625
# 0 days 00:00:00.012000 -1.45125  0.70125
# 0 days 00:00:00.016000 -1.44375  0.67875
# ...                         ...      ...
# 1 days 01:08:09.980000 -0.03625  0.02250
# 1 days 01:08:09.984000 -0.03625  0.02250
# 1 days 01:08:09.988000 -0.04000  0.02375
# 1 days 01:08:09.992000 -0.04000  0.02625
# 1 days 01:08:09.996000 -0.04125  0.02375
#
# [22622500 rows x 2 columns]

# %%
r = wfdb.rdrecord('/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/43')
r.to_dataframe()
# Out:
#                             ECG      ECG
# 0 days 00:00:00        -0.07375 -0.02750
# 0 days 00:00:00.004000 -0.07125 -0.03125
# 0 days 00:00:00.008000 -0.06500 -0.03250
# 0 days 00:00:00.012000 -0.06875 -0.03375
# 0 days 00:00:00.016000 -0.06500 -0.03625
# ...                         ...      ...
# 0 days 23:07:49.980000  0.13000  0.17625
# 0 days 23:07:49.984000  0.12750  0.17375
# 0 days 23:07:49.988000  0.12875  0.17500
# 0 days 23:07:49.992000  0.13500  0.17625
# 0 days 23:07:49.996000  0.13000  0.17875
#
# [20817500 rows x 2 columns]

# %%
r

# %%
scdh_records
# Out:
# ['/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/42.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/43.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/41.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/40.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/50.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/44.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/45.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/51.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/47.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/52.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/46.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/35.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/34.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/36.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/37.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/33.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/32.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/30.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/31.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/39.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/38.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/48.hea',
#  '/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/49.hea']

# %%
scdh_d
# Out:
# {'ECG': 46}

# %%
record = wfdb.rdrecord('/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/sudden-cardiac-death-holter-database-1.0.0/30')

# %%
record.to_dataframe().resample('5S').first()
# Out:
#                      ECG      ECG
# 0 days 00:00:00  0.06375  0.18125
# 0 days 00:00:05 -0.04000  0.08750
# 0 days 00:00:10 -0.03250  0.02750
# 0 days 00:00:15 -0.10625 -0.02000
# 0 days 00:00:20 -0.05250 -0.06625
# ...                  ...      ...
# 1 days 00:32:55  0.30875 -0.01000
# 1 days 00:33:00  0.06250  0.21750
# 1 days 00:33:05  0.07250  0.15500
# 1 days 00:33:10 -0.01625  0.07500
# 1 days 00:33:15 -0.00875  0.00750
#
# [17680 rows x 2 columns]

# %%
all_downloaded = glob.glob("/Users/michaelscott/bd4h/project/streaming-env/time-series-kafka-demo/data/waveform/physionet.org/files/mimic3wdb-matched/1.0/p00/p000020)
